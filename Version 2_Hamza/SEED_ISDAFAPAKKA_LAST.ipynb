# %%
from torcheeg.datasets import SEEDDataset
from torcheeg import transforms

raw_dataset = SEEDDataset(
    root_path='./SEED/SEED_EEG/Preprocessed_EEG',
    io_path = 'E:/FYP/Egg-Based Emotion Recognition/EEg-based-Emotion-Recognition/.torcheeg/datasets_1733174610032_5iJyS',
    online_transform=None,  # Disable transforms
    label_transform=None,
    num_worker=4
)

raw_sample = raw_dataset[0]
print(f"Raw EEG data shape: {raw_sample[0].shape}")  # Should be [62, ...] for SEED
print(f"Label: {raw_sample[1]}")  # Should be a number between 0 and 3
# Out:
# [2024-12-12 01:04:12] INFO (torcheeg/MainThread) 🔍 | Detected cached processing results, reading cache from E:/FYP/Egg-Based Emotion Recognition/EEg-based-Emotion-Recognition/.torcheeg/datasets_1733174610032_5iJyS.
# Raw EEG data shape: (62, 200)
# Label: {'start_at': 0, 'end_at': 200, 'clip_id': '10_20131130.mat_0', 'subject_id': 10, 'trial_id': 'ww_eeg1', 'emotion': 1, 'date': 20131130, '_record_id': '_record_0'}

# %%
from collections import Counter

# Collect all emotion labels
emotion_counts = Counter()

for sample in raw_dataset:
    emotion = sample[1]['emotion']
    emotion_counts[emotion] += 1

# Display the counts for each emotion
print("Emotion Distribution:")
for emotion, count in sorted(emotion_counts.items()):
    label = "Negative" if emotion == -1 else "Neutral" if emotion == 0 else "Positive"
    print(f"{label} ({emotion}): {count}")
# Out:
# Emotion Distribution:
# Negative (-1): 50400
# Neutral (0): 49680
# Positive (1): 52650

# %%
import numpy as np
from scipy.signal import butter, filtfilt

def bandpass_filter(data, lowcut=4, highcut=47, fs=200, order=4):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, data, axis=1)

# %%
filtered_data_list = []
labels_list = []

for idx in range(len(raw_dataset)):
    eeg_data, label = raw_dataset[idx]
    
    # Apply the bandpass filter
    filtered_data = bandpass_filter(eeg_data, lowcut=4, highcut=47, fs=200)
    
    # Store the filtered data and corresponding label
    filtered_data_list.append(filtered_data)
    labels_list.append(label)

    # Print progress
    if idx % 5 == 0:
        print(f"Processed sample {idx}/{len(raw_dataset)}")

print("Bandpass filtering completed for all samples.")

# Verify the shape of the filtered data
print(f"Filtered EEG Data Shape: {filtered_data_list[0].shape}")
print(f"Label: {labels_list[0]}")
# Out:
# Processed sample 0/152730
# Processed sample 5/152730
# Processed sample 10/152730
# Processed sample 15/152730
# Processed sample 20/152730
# Processed sample 25/152730
# Processed sample 30/152730
# Processed sample 35/152730
# Processed sample 40/152730
# Processed sample 45/152730
# Processed sample 50/152730
# Processed sample 55/152730
# Processed sample 60/152730
# Processed sample 65/152730
# Processed sample 70/152730
# Processed sample 75/152730
# Processed sample 80/152730
# Processed sample 85/152730
# Processed sample 90/152730
# Processed sample 95/152730
# Processed sample 100/152730
# Processed sample 105/152730
# Processed sample 110/152730
# Processed sample 115/152730
# Processed sample 120/152730
# Processed sample 125/152730
# Processed sample 130/152730
# Processed sample 135/152730
# Processed sample 140/152730
# Processed sample 145/152730
# Processed sample 150/152730
# Processed sample 155/152730
# Processed sample 160/152730
# Processed sample 165/152730
# Processed sample 170/152730
# Processed sample 175/152730
# Processed sample 180/152730
# Processed sample 185/152730
# Processed sample 190/152730
# Processed sample 195/152730
# Processed sample 200/152730
# Processed sample 205/152730
# Processed sample 210/152730
# Processed sample 215/152730
# Processed sample 220/152730
# Processed sample 225/152730
# Processed sample 230/152730
# Processed sample 235/152730
# Processed sample 240/152730
# Processed sample 245/152730
# Processed sample 250/152730
# Processed sample 255/152730
# Processed sample 260/152730
# Processed sample 265/152730
# Processed sample 270/152730
# Processed sample 275/152730
# Processed sample 280/152730
# Processed sample 285/152730
# Processed sample 290/152730
# Processed sample 295/152730
# Processed sample 300/152730
# Processed sample 305/152730
# Processed sample 310/152730
# Processed sample 315/152730
# Processed sample 320/152730
# Processed sample 325/152730
# Processed sample 330/152730
# Processed sample 335/152730
# Processed sample 340/152730
# Processed sample 345/152730
# Processed sample 350/152730
# Processed sample 355/152730
# Processed sample 360/152730
# Processed sample 365/152730
# Processed sample 370/152730
# Processed sample 375/152730
# Processed sample 380/152730
# Processed sample 385/152730
# Processed sample 390/152730
# Processed sample 395/152730
# Processed sample 400/152730
# Processed sample 405/152730
# Processed sample 410/152730
# Processed sample 415/152730
# Processed sample 420/152730
# Processed sample 425/152730
# Processed sample 430/152730
# Processed sample 435/152730
# Processed sample 440/152730
# Processed sample 445/152730
# Processed sample 450/152730
# Processed sample 455/152730
# Processed sample 460/152730
# Processed sample 465/152730
# Processed sample 470/152730
# Processed sample 475/152730
# Processed sample 480/152730
# Processed sample 485/152730
# Processed sample 490/152730
# Processed sample 495/152730
# Processed sample 500/152730
# Processed sample 505/152730
# Processed sample 510/152730
# Processed sample 515/152730
# Processed sample 520/152730
# Processed sample 525/152730
# Processed sample 530/152730
# Processed sample 535/152730
# Processed sample 540/152730
# Processed sample 545/152730
# Processed sample 550/152730
# Processed sample 555/152730
# Processed sample 560/152730
# Processed sample 565/152730
# Processed sample 570/152730
# Processed sample 575/152730
# Processed sample 580/152730
# Processed sample 585/152730
# Processed sample 590/152730
# Processed sample 595/152730
# Processed sample 600/152730
# Processed sample 605/152730
# Processed sample 610/152730
# Processed sample 615/152730
# Processed sample 620/152730
# Processed sample 625/152730
# Processed sample 630/152730
# Processed sample 635/152730
# Processed sample 640/152730
# Processed sample 645/152730
# Processed sample 650/152730
# Processed sample 655/152730
# Processed sample 660/152730
# Processed sample 665/152730
# Processed sample 670/152730
# Processed sample 675/152730
# Processed sample 680/152730
# Processed sample 685/152730
# Processed sample 690/152730
# Processed sample 695/152730
# Processed sample 700/152730
# Processed sample 705/152730
# Processed sample 710/152730
# Processed sample 715/152730
# Processed sample 720/152730
# Processed sample 725/152730
# Processed sample 730/152730
# Processed sample 735/152730
# Processed sample 740/152730
# Processed sample 745/152730
# Processed sample 750/152730
# Processed sample 755/152730
# Processed sample 760/152730
# Processed sample 765/152730
# Processed sample 770/152730
# Processed sample 775/152730
# Processed sample 780/152730
# Processed sample 785/152730
# Processed sample 790/152730
# Processed sample 795/152730
# Processed sample 800/152730
# Processed sample 805/152730
# Processed sample 810/152730
# Processed sample 815/152730
# Processed sample 820/152730
# Processed sample 825/152730
# Processed sample 830/152730
# Processed sample 835/152730
# Processed sample 840/152730
# Processed sample 845/152730
# Processed sample 850/152730
# Processed sample 855/152730
# Processed sample 860/152730
# Processed sample 865/152730
# Processed sample 870/152730
# Processed sample 875/152730
# Processed sample 880/152730
# Processed sample 885/152730
# Processed sample 890/152730
# Processed sample 895/152730
# Processed sample 900/152730
# Processed sample 905/152730
# Processed sample 910/152730
# Processed sample 915/152730
# Processed sample 920/152730
# Processed sample 925/152730
# Processed sample 930/152730
# Processed sample 935/152730
# Processed sample 940/152730
# Processed sample 945/152730
# Processed sample 950/152730
# Processed sample 955/152730
# Processed sample 960/152730
# Processed sample 965/152730
# Processed sample 970/152730
# Processed sample 975/152730
# Processed sample 980/152730
# Processed sample 985/152730
# Processed sample 990/152730
# Processed sample 995/152730
# Processed sample 1000/152730
# Processed sample 1005/152730
# Processed sample 1010/152730
# Processed sample 1015/152730
# Processed sample 1020/152730
# Processed sample 1025/152730
# Processed sample 1030/152730
# Processed sample 1035/152730
# Processed sample 1040/152730
# Processed sample 1045/152730
# Processed sample 1050/152730
# Processed sample 1055/152730
# Processed sample 1060/152730
# Processed sample 1065/152730
# Processed sample 1070/152730
# Processed sample 1075/152730
# Processed sample 1080/152730
# Processed sample 1085/152730
# Processed sample 1090/152730
# Processed sample 1095/152730
# Processed sample 1100/152730
# Processed sample 1105/152730
# Processed sample 1110/152730
# Processed sample 1115/152730
# Processed sample 1120/152730
# Processed sample 1125/152730
# Processed sample 1130/152730
# Processed sample 1135/152730
# Processed sample 1140/152730
# Processed sample 1145/152730
# Processed sample 1150/152730
# Processed sample 1155/152730
# Processed sample 1160/152730
# Processed sample 1165/152730
# Processed sample 1170/152730
# Processed sample 1175/152730
# Processed sample 1180/152730
# Processed sample 1185/152730
# Processed sample 1190/152730
# Processed sample 1195/152730
# Processed sample 1200/152730
# Processed sample 1205/152730
# Processed sample 1210/152730
# Processed sample 1215/152730
# Processed sample 1220/152730
# Processed sample 1225/152730
# Processed sample 1230/152730
# Processed sample 1235/152730
# Processed sample 1240/152730
# Processed sample 1245/152730
# Processed sample 1250/152730
# Processed sample 1255/152730
# Processed sample 1260/152730
# Processed sample 1265/152730
# Processed sample 1270/152730
# Processed sample 1275/152730
# Processed sample 1280/152730
# Processed sample 1285/152730
# Processed sample 1290/152730
# Processed sample 1295/152730
# Processed sample 1300/152730
# Processed sample 1305/152730
# Processed sample 1310/152730
# Processed sample 1315/152730
# Processed sample 1320/152730
# Processed sample 1325/152730
# Processed sample 1330/152730
# Processed sample 1335/152730
# Processed sample 1340/152730
# Processed sample 1345/152730
# Processed sample 1350/152730
# Processed sample 1355/152730
# Processed sample 1360/152730
# Processed sample 1365/152730
# Processed sample 1370/152730
# Processed sample 1375/152730
# Processed sample 1380/152730
# Processed sample 1385/152730
# Processed sample 1390/152730
# Processed sample 1395/152730
# Processed sample 1400/152730
# Processed sample 1405/152730
# Processed sample 1410/152730
# Processed sample 1415/152730
# Processed sample 1420/152730
# Processed sample 1425/152730
# Processed sample 1430/152730
# Processed sample 1435/152730
# Processed sample 1440/152730
# Processed sample 1445/152730
# Processed sample 1450/152730
# Processed sample 1455/152730
# Processed sample 1460/152730
# Processed sample 1465/152730
# Processed sample 1470/152730
# Processed sample 1475/152730
# Processed sample 1480/152730
# Processed sample 1485/152730
# Processed sample 1490/152730
# Processed sample 1495/152730
# Processed sample 1500/152730
# Processed sample 1505/152730
# Processed sample 1510/152730
# Processed sample 1515/152730
# Processed sample 1520/152730
# Processed sample 1525/152730
# Processed sample 1530/152730
# Processed sample 1535/152730
# Processed sample 1540/152730
# Processed sample 1545/152730
# Processed sample 1550/152730
# Processed sample 1555/152730
# Processed sample 1560/152730
# Processed sample 1565/152730
# Processed sample 1570/152730
# Processed sample 1575/152730
# Processed sample 1580/152730
# Processed sample 1585/152730
# Processed sample 1590/152730
# Processed sample 1595/152730
# Processed sample 1600/152730
# Processed sample 1605/152730
# Processed sample 1610/152730
# Processed sample 1615/152730
# Processed sample 1620/152730
# Processed sample 1625/152730
# Processed sample 1630/152730
# Processed sample 1635/152730
# Processed sample 1640/152730
# Processed sample 1645/152730
# Processed sample 1650/152730
# Processed sample 1655/152730
# Processed sample 1660/152730
# Processed sample 1665/152730
# Processed sample 1670/152730
# Processed sample 1675/152730
# Processed sample 1680/152730
# Processed sample 1685/152730
# Processed sample 1690/152730
# Processed sample 1695/152730
# Processed sample 1700/152730
# Processed sample 1705/152730
# Processed sample 1710/152730
# Processed sample 1715/152730
# Processed sample 1720/152730
# Processed sample 1725/152730
# Processed sample 1730/152730
# Processed sample 1735/152730
# Processed sample 1740/152730
# Processed sample 1745/152730
# Processed sample 1750/152730
# Processed sample 1755/152730
# Processed sample 1760/152730
# Processed sample 1765/152730
# Processed sample 1770/152730
# Processed sample 1775/152730
# Processed sample 1780/152730
# Processed sample 1785/152730
# Processed sample 1790/152730
# Processed sample 1795/152730
# Processed sample 1800/152730
# Processed sample 1805/152730
# Processed sample 1810/152730
# Processed sample 1815/152730
# Processed sample 1820/152730
# Processed sample 1825/152730
# Processed sample 1830/152730
# Processed sample 1835/152730
# Processed sample 1840/152730
# Processed sample 1845/152730
# Processed sample 1850/152730
# Processed sample 1855/152730
# Processed sample 1860/152730
# Processed sample 1865/152730
# Processed sample 1870/152730
# Processed sample 1875/152730
# Processed sample 1880/152730
# Processed sample 1885/152730
# Processed sample 1890/152730
# Processed sample 1895/152730
# Processed sample 1900/152730
# Processed sample 1905/152730
# Processed sample 1910/152730
# Processed sample 1915/152730
# Processed sample 1920/152730
# Processed sample 1925/152730
# Processed sample 1930/152730
# Processed sample 1935/152730
# Processed sample 1940/152730
# Processed sample 1945/152730
# Processed sample 1950/152730
# Processed sample 1955/152730
# Processed sample 1960/152730
# Processed sample 1965/152730
# Processed sample 1970/152730
# Processed sample 1975/152730
# Processed sample 1980/152730
# Processed sample 1985/152730
# Processed sample 1990/152730
# Processed sample 1995/152730
# Processed sample 2000/152730
# Processed sample 2005/152730
# Processed sample 2010/152730
# Processed sample 2015/152730
# Processed sample 2020/152730
# Processed sample 2025/152730
# Processed sample 2030/152730
# Processed sample 2035/152730
# Processed sample 2040/152730
# Processed sample 2045/152730
# Processed sample 2050/152730
# Processed sample 2055/152730
# Processed sample 2060/152730
# Processed sample 2065/152730
# Processed sample 2070/152730
# Processed sample 2075/152730
# Processed sample 2080/152730
# Processed sample 2085/152730
# Processed sample 2090/152730
# Processed sample 2095/152730
# Processed sample 2100/152730
# Processed sample 2105/152730
# Processed sample 2110/152730
# Processed sample 2115/152730
# Processed sample 2120/152730
# Processed sample 2125/152730
# Processed sample 2130/152730
# Processed sample 2135/152730
# Processed sample 2140/152730
# Processed sample 2145/152730
# Processed sample 2150/152730
# Processed sample 2155/152730
# Processed sample 2160/152730
# Processed sample 2165/152730
# Processed sample 2170/152730
# Processed sample 2175/152730
# Processed sample 2180/152730
# Processed sample 2185/152730
# Processed sample 2190/152730
# Processed sample 2195/152730
# Processed sample 2200/152730
# Processed sample 2205/152730
# Processed sample 2210/152730
# Processed sample 2215/152730
# Processed sample 2220/152730
# Processed sample 2225/152730
# Processed sample 2230/152730
# Processed sample 2235/152730
# Processed sample 2240/152730
# Processed sample 2245/152730
# Processed sample 2250/152730
# Processed sample 2255/152730
# Processed sample 2260/152730
# Processed sample 2265/152730
# Processed sample 2270/152730
# Processed sample 2275/152730
# Processed sample 2280/152730
# Processed sample 2285/152730
# Processed sample 2290/152730
# Processed sample 2295/152730
# Processed sample 2300/152730
# Processed sample 2305/152730
# Processed sample 2310/152730
# Processed sample 2315/152730
# Processed sample 2320/152730
# Processed sample 2325/152730
# Processed sample 2330/152730
# Processed sample 2335/152730
# Processed sample 2340/152730
# Processed sample 2345/152730
# Processed sample 2350/152730
# Processed sample 2355/152730
# Processed sample 2360/152730
# Processed sample 2365/152730
# Processed sample 2370/152730
# Processed sample 2375/152730
# Processed sample 2380/152730
# Processed sample 2385/152730
# Processed sample 2390/152730
# Processed sample 2395/152730
# Processed sample 2400/152730
# Processed sample 2405/152730
# Processed sample 2410/152730
# Processed sample 2415/152730
# Processed sample 2420/152730
# Processed sample 2425/152730
# Processed sample 2430/152730
# Processed sample 2435/152730
# Processed sample 2440/152730
# Processed sample 2445/152730
# Processed sample 2450/152730
# Processed sample 2455/152730
# Processed sample 2460/152730
# Processed sample 2465/152730
# Processed sample 2470/152730
# Processed sample 2475/152730
# Processed sample 2480/152730
# Processed sample 2485/152730
# Processed sample 2490/152730
# Processed sample 2495/152730
# Processed sample 2500/152730
# Processed sample 2505/152730
# Processed sample 2510/152730
# Processed sample 2515/152730
# Processed sample 2520/152730
# Processed sample 2525/152730
# Processed sample 2530/152730
# Processed sample 2535/152730
# Processed sample 2540/152730
# Processed sample 2545/152730
# Processed sample 2550/152730
# Processed sample 2555/152730
# Processed sample 2560/152730
# Processed sample 2565/152730
# Processed sample 2570/152730
# Processed sample 2575/152730
# Processed sample 2580/152730
# Processed sample 2585/152730
# Processed sample 2590/152730
# Processed sample 2595/152730
# Processed sample 2600/152730
# Processed sample 2605/152730
# Processed sample 2610/152730
# Processed sample 2615/152730
# Processed sample 2620/152730
# Processed sample 2625/152730
# Processed sample 2630/152730
# Processed sample 2635/152730
# Processed sample 2640/152730
# Processed sample 2645/152730
# Processed sample 2650/152730
# Processed sample 2655/152730
# Processed sample 2660/152730
# Processed sample 2665/152730
# Processed sample 2670/152730
# Processed sample 2675/152730
# Processed sample 2680/152730
# Processed sample 2685/152730
# Processed sample 2690/152730
# Processed sample 2695/152730
# Processed sample 2700/152730
# Processed sample 2705/152730
# Processed sample 2710/152730
# Processed sample 2715/152730
# Processed sample 2720/152730
# Processed sample 2725/152730
# Processed sample 2730/152730
# Processed sample 2735/152730
# Processed sample 2740/152730
# Processed sample 2745/152730
# Processed sample 2750/152730
# Processed sample 2755/152730
# Processed sample 2760/152730
# Processed sample 2765/152730
# Processed sample 2770/152730
# Processed sample 2775/152730
# Processed sample 2780/152730
# Processed sample 2785/152730
# Processed sample 2790/152730
# Processed sample 2795/152730
# Processed sample 2800/152730
# Processed sample 2805/152730
# Processed sample 2810/152730
# Processed sample 2815/152730
# Processed sample 2820/152730
# Processed sample 2825/152730
# Processed sample 2830/152730
# Processed sample 2835/152730
# Processed sample 2840/152730
# Processed sample 2845/152730
# Processed sample 2850/152730
# Processed sample 2855/152730
# Processed sample 2860/152730
# Processed sample 2865/152730
# Processed sample 2870/152730
# Processed sample 2875/152730
# Processed sample 2880/152730
# Processed sample 2885/152730
# Processed sample 2890/152730
# Processed sample 2895/152730
# Processed sample 2900/152730
# Processed sample 2905/152730
# Processed sample 2910/152730
# Processed sample 2915/152730
# Processed sample 2920/152730
# Processed sample 2925/152730
# Processed sample 2930/152730
# Processed sample 2935/152730
# Processed sample 2940/152730
# Processed sample 2945/152730
# Processed sample 2950/152730
# Processed sample 2955/152730
# Processed sample 2960/152730
# Processed sample 2965/152730
# Processed sample 2970/152730
# Processed sample 2975/152730
# Processed sample 2980/152730
# Processed sample 2985/152730
# Processed sample 2990/152730
# Processed sample 2995/152730
# Processed sample 3000/152730
# Processed sample 3005/152730
# Processed sample 3010/152730
# Processed sample 3015/152730
# Processed sample 3020/152730
# Processed sample 3025/152730
# Processed sample 3030/152730
# Processed sample 3035/152730
# Processed sample 3040/152730
# Processed sample 3045/152730
# Processed sample 3050/152730
# Processed sample 3055/152730
# Processed sample 3060/152730
# Processed sample 3065/152730
# Processed sample 3070/152730
# Processed sample 3075/152730
# Processed sample 3080/152730
# Processed sample 3085/152730
# Processed sample 3090/152730
# Processed sample 3095/152730
# Processed sample 3100/152730
# Processed sample 3105/152730
# Processed sample 3110/152730
# Processed sample 3115/152730
# Processed sample 3120/152730
# Processed sample 3125/152730
# Processed sample 3130/152730
# Processed sample 3135/152730
# Processed sample 3140/152730
# Processed sample 3145/152730
# Processed sample 3150/152730
# Processed sample 3155/152730
# Processed sample 3160/152730
# Processed sample 3165/152730
# Processed sample 3170/152730
# Processed sample 3175/152730
# Processed sample 3180/152730
# Processed sample 3185/152730
# Processed sample 3190/152730
# Processed sample 3195/152730
# Processed sample 3200/152730
# Processed sample 3205/152730
# Processed sample 3210/152730
# Processed sample 3215/152730
# Processed sample 3220/152730
# Processed sample 3225/152730
# Processed sample 3230/152730
# Processed sample 3235/152730
# Processed sample 3240/152730
# Processed sample 3245/152730
# Processed sample 3250/152730
# Processed sample 3255/152730
# Processed sample 3260/152730
# Processed sample 3265/152730
# Processed sample 3270/152730
# Processed sample 3275/152730
# Processed sample 3280/152730
# Processed sample 3285/152730
# Processed sample 3290/152730
# Processed sample 3295/152730
# Processed sample 3300/152730
# Processed sample 3305/152730
# Processed sample 3310/152730
# Processed sample 3315/152730
# Processed sample 3320/152730
# Processed sample 3325/152730
# Processed sample 3330/152730
# Processed sample 3335/152730
# Processed sample 3340/152730
# Processed sample 3345/152730
# Processed sample 3350/152730
# Processed sample 3355/152730
# Processed sample 3360/152730
# Processed sample 3365/152730
# Processed sample 3370/152730
# Processed sample 3375/152730
# Processed sample 3380/152730
# Processed sample 3385/152730
# Processed sample 3390/152730
# Processed sample 3395/152730
# Processed sample 3400/152730
# Processed sample 3405/152730
# Processed sample 3410/152730
# Processed sample 3415/152730
# Processed sample 3420/152730
# Processed sample 3425/152730
# Processed sample 3430/152730
# Processed sample 3435/152730
# Processed sample 3440/152730
# Processed sample 3445/152730
# Processed sample 3450/152730
# Processed sample 3455/152730
# Processed sample 3460/152730
# Processed sample 3465/152730
# Processed sample 3470/152730
# Processed sample 3475/152730
# Processed sample 3480/152730
# Processed sample 3485/152730
# Processed sample 3490/152730
# Processed sample 3495/152730
# Processed sample 3500/152730
# Processed sample 3505/152730
# Processed sample 3510/152730
# Processed sample 3515/152730
# Processed sample 3520/152730
# Processed sample 3525/152730
# Processed sample 3530/152730
# Processed sample 3535/152730
# Processed sample 3540/152730
# Processed sample 3545/152730
# Processed sample 3550/152730
# Processed sample 3555/152730
# Processed sample 3560/152730
# Processed sample 3565/152730
# Processed sample 3570/152730
# Processed sample 3575/152730
# Processed sample 3580/152730
# Processed sample 3585/152730
# Processed sample 3590/152730
# Processed sample 3595/152730
# Processed sample 3600/152730
# Processed sample 3605/152730
# Processed sample 3610/152730
# Processed sample 3615/152730
# Processed sample 3620/152730
# Processed sample 3625/152730
# Processed sample 3630/152730
# Processed sample 3635/152730
# Processed sample 3640/152730
# Processed sample 3645/152730
# Processed sample 3650/152730
# Processed sample 3655/152730
# Processed sample 3660/152730
# Processed sample 3665/152730
# Processed sample 3670/152730
# Processed sample 3675/152730
# Processed sample 3680/152730
# Processed sample 3685/152730
# Processed sample 3690/152730
# Processed sample 3695/152730
# Processed sample 3700/152730
# Processed sample 3705/152730
# Processed sample 3710/152730
# Processed sample 3715/152730
# Processed sample 3720/152730
# Processed sample 3725/152730
# Processed sample 3730/152730
# Processed sample 3735/152730
# Processed sample 3740/152730
# Processed sample 3745/152730
# Processed sample 3750/152730
# Processed sample 3755/152730
# Processed sample 3760/152730
# Processed sample 3765/152730
# Processed sample 3770/152730
# Processed sample 3775/152730
# Processed sample 3780/152730
# Processed sample 3785/152730
# Processed sample 3790/152730
# Processed sample 3795/152730
# Processed sample 3800/152730
# Processed sample 3805/152730
# Processed sample 3810/152730
# Processed sample 3815/152730
# Processed sample 3820/152730
# Processed sample 3825/152730
# Processed sample 3830/152730
# Processed sample 3835/152730
# Processed sample 3840/152730
# Processed sample 3845/152730
# Processed sample 3850/152730
# Processed sample 3855/152730
# Processed sample 3860/152730
# Processed sample 3865/152730
# Processed sample 3870/152730
# Processed sample 3875/152730
# Processed sample 3880/152730
# Processed sample 3885/152730
# Processed sample 3890/152730
# Processed sample 3895/152730
# Processed sample 3900/152730
# Processed sample 3905/152730
# Processed sample 3910/152730
# Processed sample 3915/152730
# Processed sample 3920/152730
# Processed sample 3925/152730
# Processed sample 3930/152730
# Processed sample 3935/152730
# Processed sample 3940/152730
# Processed sample 3945/152730
# Processed sample 3950/152730
# Processed sample 3955/152730
# Processed sample 3960/152730
# Processed sample 3965/152730
# Processed sample 3970/152730
# Processed sample 3975/152730
# Processed sample 3980/152730
# Processed sample 3985/152730
# Processed sample 3990/152730
# Processed sample 3995/152730
# Processed sample 4000/152730
# Processed sample 4005/152730
# Processed sample 4010/152730
# Processed sample 4015/152730
# Processed sample 4020/152730
# Processed sample 4025/152730
# Processed sample 4030/152730
# Processed sample 4035/152730
# Processed sample 4040/152730
# Processed sample 4045/152730
# Processed sample 4050/152730
# Processed sample 4055/152730
# Processed sample 4060/152730
# Processed sample 4065/152730
# Processed sample 4070/152730
# Processed sample 4075/152730
# Processed sample 4080/152730
# Processed sample 4085/152730
# Processed sample 4090/152730
# Processed sample 4095/152730
# Processed sample 4100/152730
# Processed sample 4105/152730
# Processed sample 4110/152730
# Processed sample 4115/152730
# Processed sample 4120/152730
# Processed sample 4125/152730
# Processed sample 4130/152730
# Processed sample 4135/152730
# Processed sample 4140/152730
# Processed sample 4145/152730
# Processed sample 4150/152730
# Processed sample 4155/152730
# Processed sample 4160/152730
# Processed sample 4165/152730
# Processed sample 4170/152730
# Processed sample 4175/152730
# Processed sample 4180/152730
# Processed sample 4185/152730
# Processed sample 4190/152730
# Processed sample 4195/152730
# Processed sample 4200/152730
# Processed sample 4205/152730
# Processed sample 4210/152730
# Processed sample 4215/152730
# Processed sample 4220/152730
# Processed sample 4225/152730
# Processed sample 4230/152730
# Processed sample 4235/152730
# Processed sample 4240/152730
# Processed sample 4245/152730
# Processed sample 4250/152730
# Processed sample 4255/152730
# Processed sample 4260/152730
# Processed sample 4265/152730
# Processed sample 4270/152730
# Processed sample 4275/152730
# Processed sample 4280/152730
# Processed sample 4285/152730
# Processed sample 4290/152730
# Processed sample 4295/152730
# Processed sample 4300/152730
# Processed sample 4305/152730
# Processed sample 4310/152730
# Processed sample 4315/152730
# Processed sample 4320/152730
# Processed sample 4325/152730
# Processed sample 4330/152730
# Processed sample 4335/152730
# Processed sample 4340/152730
# Processed sample 4345/152730
# Processed sample 4350/152730
# Processed sample 4355/152730
# Processed sample 4360/152730
# Processed sample 4365/152730
# Processed sample 4370/152730
# Processed sample 4375/152730
# Processed sample 4380/152730
# Processed sample 4385/152730
# Processed sample 4390/152730
# Processed sample 4395/152730
# Processed sample 4400/152730
# Processed sample 4405/152730
# Processed sample 4410/152730
# Processed sample 4415/152730
# Processed sample 4420/152730
# Processed sample 4425/152730
# Processed sample 4430/152730
# Processed sample 4435/152730
# Processed sample 4440/152730
# Processed sample 4445/152730
# Processed sample 4450/152730
# Processed sample 4455/152730
# Processed sample 4460/152730
# Processed sample 4465/152730
# Processed sample 4470/152730
# Processed sample 4475/152730
# Processed sample 4480/152730
# Processed sample 4485/152730
# Processed sample 4490/152730
# Processed sample 4495/152730
# Processed sample 4500/152730
# Processed sample 4505/152730
# Processed sample 4510/152730
# Processed sample 4515/152730
# Processed sample 4520/152730
# Processed sample 4525/152730
# Processed sample 4530/152730
# Processed sample 4535/152730
# Processed sample 4540/152730
# Processed sample 4545/152730
# Processed sample 4550/152730
# Processed sample 4555/152730
# Processed sample 4560/152730
# Processed sample 4565/152730
# Processed sample 4570/152730
# Processed sample 4575/152730
# Processed sample 4580/152730
# Processed sample 4585/152730
# Processed sample 4590/152730
# Processed sample 4595/152730
# Processed sample 4600/152730
# Processed sample 4605/152730
# Processed sample 4610/152730
# Processed sample 4615/152730
# Processed sample 4620/152730
# Processed sample 4625/152730
# Processed sample 4630/152730
# Processed sample 4635/152730
# Processed sample 4640/152730
# Processed sample 4645/152730
# Processed sample 4650/152730
# Processed sample 4655/152730
# Processed sample 4660/152730
# Processed sample 4665/152730
# Processed sample 4670/152730
# Processed sample 4675/152730
# Processed sample 4680/152730
# Processed sample 4685/152730
# Processed sample 4690/152730
# Processed sample 4695/152730
# Processed sample 4700/152730
# Processed sample 4705/152730
# Processed sample 4710/152730
# Processed sample 4715/152730
# Processed sample 4720/152730
# Processed sample 4725/152730
# Processed sample 4730/152730
# Processed sample 4735/152730
# Processed sample 4740/152730
# Processed sample 4745/152730
# Processed sample 4750/152730
# Processed sample 4755/152730
# Processed sample 4760/152730
# Processed sample 4765/152730
# Processed sample 4770/152730
# Processed sample 4775/152730
# Processed sample 4780/152730
# Processed sample 4785/152730
# Processed sample 4790/152730
# Processed sample 4795/152730
# Processed sample 4800/152730
# Processed sample 4805/152730
# Processed sample 4810/152730
# Processed sample 4815/152730
# Processed sample 4820/152730
# Processed sample 4825/152730
# Processed sample 4830/152730
# Processed sample 4835/152730
# Processed sample 4840/152730
# Processed sample 4845/152730
# Processed sample 4850/152730
# Processed sample 4855/152730
# Processed sample 4860/152730
# Processed sample 4865/152730
# Processed sample 4870/152730
# Processed sample 4875/152730
# Processed sample 4880/152730
# Processed sample 4885/152730
# Processed sample 4890/152730
# Processed sample 4895/152730
# Processed sample 4900/152730
# Processed sample 4905/152730
# Processed sample 4910/152730
# Processed sample 4915/152730
# Processed sample 4920/152730
# Processed sample 4925/152730
# Processed sample 4930/152730
# Processed sample 4935/152730
# Processed sample 4940/152730
# Processed sample 4945/152730
# Processed sample 4950/152730
# Processed sample 4955/152730
# Processed sample 4960/152730
# Processed sample 4965/152730
# Processed sample 4970/152730
# Processed sample 4975/152730
# Processed sample 4980/152730
# Processed sample 4985/152730
# Processed sample 4990/152730
# Processed sample 4995/152730
# Processed sample 5000/152730
# Processed sample 5005/152730
# Processed sample 5010/152730
# Processed sample 5015/152730
# Processed sample 5020/152730
# Processed sample 5025/152730
# Processed sample 5030/152730
# Processed sample 5035/152730
# Processed sample 5040/152730
# Processed sample 5045/152730
# Processed sample 5050/152730
# Processed sample 5055/152730
# Processed sample 5060/152730
# Processed sample 5065/152730
# Processed sample 5070/152730
# Processed sample 5075/152730
# Processed sample 5080/152730
# Processed sample 5085/152730
# Processed sample 5090/152730
# Processed sample 5095/152730
# Processed sample 5100/152730
# Processed sample 5105/152730
# Processed sample 5110/152730
# Processed sample 5115/152730
# Processed sample 5120/152730
# Processed sample 5125/152730
# Processed sample 5130/152730
# Processed sample 5135/152730
# Processed sample 5140/152730
# Processed sample 5145/152730
# Processed sample 5150/152730
# Processed sample 5155/152730
# Processed sample 5160/152730
# Processed sample 5165/152730
# Processed sample 5170/152730
# Processed sample 5175/152730
# Processed sample 5180/152730
# Processed sample 5185/152730
# Processed sample 5190/152730
# Processed sample 5195/152730
# Processed sample 5200/152730
# Processed sample 5205/152730
# Processed sample 5210/152730
# Processed sample 5215/152730
# Processed sample 5220/152730
# Processed sample 5225/152730
# Processed sample 5230/152730
# Processed sample 5235/152730
# Processed sample 5240/152730
# Processed sample 5245/152730
# Processed sample 5250/152730
# Processed sample 5255/152730
# Processed sample 5260/152730
# Processed sample 5265/152730
# Processed sample 5270/152730
# Processed sample 5275/152730
# Processed sample 5280/152730
# Processed sample 5285/152730
# Processed sample 5290/152730
# Processed sample 5295/152730
# Processed sample 5300/152730
# Processed sample 5305/152730
# Processed sample 5310/152730
# Processed sample 5315/152730
# Processed sample 5320/152730
# Processed sample 5325/152730
# Processed sample 5330/152730
# Processed sample 5335/152730
# Processed sample 5340/152730
# Processed sample 5345/152730
# Processed sample 5350/152730
# Processed sample 5355/152730
# Processed sample 5360/152730
# Processed sample 5365/152730
# Processed sample 5370/152730
# Processed sample 5375/152730
# Processed sample 5380/152730
# Processed sample 5385/152730
# Processed sample 5390/152730
# Processed sample 5395/152730
# Processed sample 5400/152730
# Processed sample 5405/152730
# Processed sample 5410/152730
# Processed sample 5415/152730
# Processed sample 5420/152730
# Processed sample 5425/152730
# Processed sample 5430/152730
# Processed sample 5435/152730
# Processed sample 5440/152730
# Processed sample 5445/152730
# Processed sample 5450/152730
# Processed sample 5455/152730
# Processed sample 5460/152730
# Processed sample 5465/152730
# Processed sample 5470/152730
# Processed sample 5475/152730
# Processed sample 5480/152730
# Processed sample 5485/152730
# Processed sample 5490/152730
# Processed sample 5495/152730
# Processed sample 5500/152730
# Processed sample 5505/152730
# Processed sample 5510/152730
# Processed sample 5515/152730
# Processed sample 5520/152730
# Processed sample 5525/152730
# Processed sample 5530/152730
# Processed sample 5535/152730
# Processed sample 5540/152730
# Processed sample 5545/152730
# Processed sample 5550/152730
# Processed sample 5555/152730
# Processed sample 5560/152730
# Processed sample 5565/152730
# Processed sample 5570/152730
# Processed sample 5575/152730
# Processed sample 5580/152730
# Processed sample 5585/152730
# Processed sample 5590/152730
# Processed sample 5595/152730
# Processed sample 5600/152730
# Processed sample 5605/152730
# Processed sample 5610/152730
# Processed sample 5615/152730
# Processed sample 5620/152730
# Processed sample 5625/152730
# Processed sample 5630/152730
# Processed sample 5635/152730
# Processed sample 5640/152730
# Processed sample 5645/152730
# Processed sample 5650/152730
# Processed sample 5655/152730
# Processed sample 5660/152730
# Processed sample 5665/152730
# Processed sample 5670/152730
# Processed sample 5675/152730
# Processed sample 5680/152730
# Processed sample 5685/152730
# Processed sample 5690/152730
# Processed sample 5695/152730
# Processed sample 5700/152730
# Processed sample 5705/152730
# Processed sample 5710/152730
# Processed sample 5715/152730
# Processed sample 5720/152730
# Processed sample 5725/152730
# Processed sample 5730/152730
# Processed sample 5735/152730
# Processed sample 5740/152730
# Processed sample 5745/152730
# Processed sample 5750/152730
# Processed sample 5755/152730
# Processed sample 5760/152730
# Processed sample 5765/152730
# Processed sample 5770/152730
# Processed sample 5775/152730
# Processed sample 5780/152730
# Processed sample 5785/152730
# Processed sample 5790/152730
# Processed sample 5795/152730
# Processed sample 5800/152730
# Processed sample 5805/152730
# Processed sample 5810/152730
# Processed sample 5815/152730
# Processed sample 5820/152730
# Processed sample 5825/152730
# Processed sample 5830/152730
# Processed sample 5835/152730
# Processed sample 5840/152730
# Processed sample 5845/152730
# Processed sample 5850/152730
# Processed sample 5855/152730
# Processed sample 5860/152730
# Processed sample 5865/152730
# Processed sample 5870/152730
# Processed sample 5875/152730
# Processed sample 5880/152730
# Processed sample 5885/152730
# Processed sample 5890/152730
# Processed sample 5895/152730
# Processed sample 5900/152730
# Processed sample 5905/152730
# Processed sample 5910/152730
# Processed sample 5915/152730
# Processed sample 5920/152730
# Processed sample 5925/152730
# Processed sample 5930/152730
# Processed sample 5935/152730
# Processed sample 5940/152730
# Processed sample 5945/152730
# Processed sample 5950/152730
# Processed sample 5955/152730
# Processed sample 5960/152730
# Processed sample 5965/152730
# Processed sample 5970/152730
# Processed sample 5975/152730
# Processed sample 5980/152730
# Processed sample 5985/152730
# Processed sample 5990/152730
# Processed sample 5995/152730
# Processed sample 6000/152730
# Processed sample 6005/152730
# Processed sample 6010/152730
# Processed sample 6015/152730
# Processed sample 6020/152730
# Processed sample 6025/152730
# Processed sample 6030/152730
# Processed sample 6035/152730
# Processed sample 6040/152730
# Processed sample 6045/152730
# Processed sample 6050/152730
# Processed sample 6055/152730
# Processed sample 6060/152730
# Processed sample 6065/152730
# Processed sample 6070/152730
# Processed sample 6075/152730
# Processed sample 6080/152730
# Processed sample 6085/152730
# Processed sample 6090/152730
# Processed sample 6095/152730
# Processed sample 6100/152730
# Processed sample 6105/152730
# Processed sample 6110/152730
# Processed sample 6115/152730
# Processed sample 6120/152730
# Processed sample 6125/152730
# Processed sample 6130/152730
# Processed sample 6135/152730
# Processed sample 6140/152730
# Processed sample 6145/152730
# Processed sample 6150/152730
# Processed sample 6155/152730
# Processed sample 6160/152730
# Processed sample 6165/152730
# Processed sample 6170/152730
# Processed sample 6175/152730
# Processed sample 6180/152730
# Processed sample 6185/152730
# Processed sample 6190/152730
# Processed sample 6195/152730
# Processed sample 6200/152730
# Processed sample 6205/152730
# Processed sample 6210/152730
# Processed sample 6215/152730
# Processed sample 6220/152730
# Processed sample 6225/152730
# Processed sample 6230/152730
# Processed sample 6235/152730
# Processed sample 6240/152730
# Processed sample 6245/152730
# Processed sample 6250/152730
# Processed sample 6255/152730
# Processed sample 6260/152730
# Processed sample 6265/152730
# Processed sample 6270/152730
# Processed sample 6275/152730
# Processed sample 6280/152730
# Processed sample 6285/152730
# Processed sample 6290/152730
# Processed sample 6295/152730
# Processed sample 6300/152730
# Processed sample 6305/152730
# Processed sample 6310/152730
# Processed sample 6315/152730
# Processed sample 6320/152730
# Processed sample 6325/152730
# Processed sample 6330/152730
# Processed sample 6335/152730
# Processed sample 6340/152730
# Processed sample 6345/152730
# Processed sample 6350/152730
# Processed sample 6355/152730
# Processed sample 6360/152730
# Processed sample 6365/152730
# Processed sample 6370/152730
# Processed sample 6375/152730
# Processed sample 6380/152730
# Processed sample 6385/152730
# Processed sample 6390/152730
# Processed sample 6395/152730
# Processed sample 6400/152730
# Processed sample 6405/152730
# Processed sample 6410/152730
# Processed sample 6415/152730
# Processed sample 6420/152730
# Processed sample 6425/152730
# Processed sample 6430/152730
# Processed sample 6435/152730
# Processed sample 6440/152730
# Processed sample 6445/152730
# Processed sample 6450/152730
# Processed sample 6455/152730
# Processed sample 6460/152730
# Processed sample 6465/152730
# Processed sample 6470/152730
# Processed sample 6475/152730
# Processed sample 6480/152730
# Processed sample 6485/152730
# Processed sample 6490/152730
# Processed sample 6495/152730
# Processed sample 6500/152730
# Processed sample 6505/152730
# Processed sample 6510/152730
# Processed sample 6515/152730
# Processed sample 6520/152730
# Processed sample 6525/152730
# Processed sample 6530/152730
# Processed sample 6535/152730
# Processed sample 6540/152730
# Processed sample 6545/152730
# Processed sample 6550/152730
# Processed sample 6555/152730
# Processed sample 6560/152730
# Processed sample 6565/152730
# Processed sample 6570/152730
# Processed sample 6575/152730
# Processed sample 6580/152730
# Processed sample 6585/152730
# Processed sample 6590/152730
# Processed sample 6595/152730
# Processed sample 6600/152730
# Processed sample 6605/152730
# Processed sample 6610/152730
# Processed sample 6615/152730
# Processed sample 6620/152730
# Processed sample 6625/152730
# Processed sample 6630/152730
# Processed sample 6635/152730
# Processed sample 6640/152730
# Processed sample 6645/152730
# Processed sample 6650/152730
# Processed sample 6655/152730
# Processed sample 6660/152730
# Processed sample 6665/152730
# Processed sample 6670/152730
# Processed sample 6675/152730
# Processed sample 6680/152730
# Processed sample 6685/152730
# Processed sample 6690/152730
# Processed sample 6695/152730
# Processed sample 6700/152730
# Processed sample 6705/152730
# Processed sample 6710/152730
# Processed sample 6715/152730
# Processed sample 6720/152730
# Processed sample 6725/152730
# Processed sample 6730/152730
# Processed sample 6735/152730
# Processed sample 6740/152730
# Processed sample 6745/152730
# Processed sample 6750/152730
# Processed sample 6755/152730
# Processed sample 6760/152730
# Processed sample 6765/152730
# Processed sample 6770/152730
# Processed sample 6775/152730
# Processed sample 6780/152730
# Processed sample 6785/152730
# Processed sample 6790/152730
# Processed sample 6795/152730
# Processed sample 6800/152730
# Processed sample 6805/152730
# Processed sample 6810/152730
# Processed sample 6815/152730
# Processed sample 6820/152730
# Processed sample 6825/152730
# Processed sample 6830/152730
# Processed sample 6835/152730
# Processed sample 6840/152730
# Processed sample 6845/152730
# Processed sample 6850/152730
# Processed sample 6855/152730
# Processed sample 6860/152730
# Processed sample 6865/152730
# Processed sample 6870/152730
# Processed sample 6875/152730
# Processed sample 6880/152730
# Processed sample 6885/152730
# Processed sample 6890/152730
# Processed sample 6895/152730
# Processed sample 6900/152730
# Processed sample 6905/152730
# Processed sample 6910/152730
# Processed sample 6915/152730
# Processed sample 6920/152730
# Processed sample 6925/152730
# Processed sample 6930/152730
# Processed sample 6935/152730
# Processed sample 6940/152730
# Processed sample 6945/152730
# Processed sample 6950/152730
# Processed sample 6955/152730
# Processed sample 6960/152730
# Processed sample 6965/152730
# Processed sample 6970/152730
# Processed sample 6975/152730
# Processed sample 6980/152730
# Processed sample 6985/152730
# Processed sample 6990/152730
# Processed sample 6995/152730
# Processed sample 7000/152730
# Processed sample 7005/152730
# Processed sample 7010/152730
# Processed sample 7015/152730
# Processed sample 7020/152730
# Processed sample 7025/152730
# Processed sample 7030/152730
# Processed sample 7035/152730
# Processed sample 7040/152730
# Processed sample 7045/152730
# Processed sample 7050/152730
# Processed sample 7055/152730
# Processed sample 7060/152730
# Processed sample 7065/152730
# Processed sample 7070/152730
# Processed sample 7075/152730
# Processed sample 7080/152730
# Processed sample 7085/152730
# Processed sample 7090/152730
# Processed sample 7095/152730
# Processed sample 7100/152730
# Processed sample 7105/152730
# Processed sample 7110/152730
# Processed sample 7115/152730
# Processed sample 7120/152730
# Processed sample 7125/152730
# Processed sample 7130/152730
# Processed sample 7135/152730
# Processed sample 7140/152730
# Processed sample 7145/152730
# Processed sample 7150/152730
# Processed sample 7155/152730
# Processed sample 7160/152730
# Processed sample 7165/152730
# Processed sample 7170/152730
# Processed sample 7175/152730
# Processed sample 7180/152730
# Processed sample 7185/152730
# Processed sample 7190/152730
# Processed sample 7195/152730
# Processed sample 7200/152730
# Processed sample 7205/152730
# Processed sample 7210/152730
# Processed sample 7215/152730
# Processed sample 7220/152730
# Processed sample 7225/152730
# Processed sample 7230/152730
# Processed sample 7235/152730
# Processed sample 7240/152730
# Processed sample 7245/152730
# Processed sample 7250/152730
# Processed sample 7255/152730
# Processed sample 7260/152730
# Processed sample 7265/152730
# Processed sample 7270/152730
# Processed sample 7275/152730
# Processed sample 7280/152730
# Processed sample 7285/152730
# Processed sample 7290/152730
# Processed sample 7295/152730
# Processed sample 7300/152730
# Processed sample 7305/152730
# Processed sample 7310/152730
# Processed sample 7315/152730
# Processed sample 7320/152730
# Processed sample 7325/152730
# Processed sample 7330/152730
# Processed sample 7335/152730
# Processed sample 7340/152730
# Processed sample 7345/152730
# Processed sample 7350/152730
# Processed sample 7355/152730
# Processed sample 7360/152730
# Processed sample 7365/152730
# Processed sample 7370/152730
# Processed sample 7375/152730
# Processed sample 7380/152730
# Processed sample 7385/152730
# Processed sample 7390/152730
# Processed sample 7395/152730
# Processed sample 7400/152730
# Processed sample 7405/152730
# Processed sample 7410/152730
# Processed sample 7415/152730
# Processed sample 7420/152730
# Processed sample 7425/152730
# Processed sample 7430/152730
# Processed sample 7435/152730
# Processed sample 7440/152730
# Processed sample 7445/152730
# Processed sample 7450/152730
# Processed sample 7455/152730
# Processed sample 7460/152730
# Processed sample 7465/152730
# Processed sample 7470/152730
# Processed sample 7475/152730
# Processed sample 7480/152730
# Processed sample 7485/152730
# Processed sample 7490/152730
# Processed sample 7495/152730
# Processed sample 7500/152730
# Processed sample 7505/152730
# Processed sample 7510/152730
# Processed sample 7515/152730
# Processed sample 7520/152730
# Processed sample 7525/152730
# Processed sample 7530/152730
# Processed sample 7535/152730
# Processed sample 7540/152730
# Processed sample 7545/152730
# Processed sample 7550/152730
# Processed sample 7555/152730
# Processed sample 7560/152730
# Processed sample 7565/152730
# Processed sample 7570/152730
# Processed sample 7575/152730
# Processed sample 7580/152730
# Processed sample 7585/152730
# Processed sample 7590/152730
# Processed sample 7595/152730
# Processed sample 7600/152730
# Processed sample 7605/152730
# Processed sample 7610/152730
# Processed sample 7615/152730
# Processed sample 7620/152730
# Processed sample 7625/152730
# Processed sample 7630/152730
# Processed sample 7635/152730
# Processed sample 7640/152730
# Processed sample 7645/152730
# Processed sample 7650/152730
# Processed sample 7655/152730
# Processed sample 7660/152730
# Processed sample 7665/152730
# Processed sample 7670/152730
# Processed sample 7675/152730
# Processed sample 7680/152730
# Processed sample 7685/152730
# Processed sample 7690/152730
# Processed sample 7695/152730
# Processed sample 7700/152730
# Processed sample 7705/152730
# Processed sample 7710/152730
# Processed sample 7715/152730
# Processed sample 7720/152730
# Processed sample 7725/152730
# Processed sample 7730/152730
# Processed sample 7735/152730
# Processed sample 7740/152730
# Processed sample 7745/152730
# Processed sample 7750/152730
# Processed sample 7755/152730
# Processed sample 7760/152730
# Processed sample 7765/152730
# Processed sample 7770/152730
# Processed sample 7775/152730
# Processed sample 7780/152730
# Processed sample 7785/152730
# Processed sample 7790/152730
# Processed sample 7795/152730
# Processed sample 7800/152730
# Processed sample 7805/152730
# Processed sample 7810/152730
# Processed sample 7815/152730
# Processed sample 7820/152730
# Processed sample 7825/152730
# Processed sample 7830/152730
# Processed sample 7835/152730
# Processed sample 7840/152730
# Processed sample 7845/152730
# Processed sample 7850/152730
# Processed sample 7855/152730
# Processed sample 7860/152730
# Processed sample 7865/152730
# Processed sample 7870/152730
# Processed sample 7875/152730
# Processed sample 7880/152730
# Processed sample 7885/152730
# Processed sample 7890/152730
# Processed sample 7895/152730
# Processed sample 7900/152730
# Processed sample 7905/152730
# Processed sample 7910/152730
# Processed sample 7915/152730
# Processed sample 7920/152730
# Processed sample 7925/152730
# Processed sample 7930/152730
# Processed sample 7935/152730
# Processed sample 7940/152730
# Processed sample 7945/152730
# Processed sample 7950/152730
# Processed sample 7955/152730
# Processed sample 7960/152730
# Processed sample 7965/152730
# Processed sample 7970/152730
# Processed sample 7975/152730
# Processed sample 7980/152730
# Processed sample 7985/152730
# Processed sample 7990/152730
# Processed sample 7995/152730
# Processed sample 8000/152730
# Processed sample 8005/152730
# Processed sample 8010/152730
# Processed sample 8015/152730
# Processed sample 8020/152730
# Processed sample 8025/152730
# Processed sample 8030/152730
# Processed sample 8035/152730
# Processed sample 8040/152730
# Processed sample 8045/152730
# Processed sample 8050/152730
# Processed sample 8055/152730
# Processed sample 8060/152730
# Processed sample 8065/152730
# Processed sample 8070/152730
# Processed sample 8075/152730
# Processed sample 8080/152730
# Processed sample 8085/152730
# Processed sample 8090/152730
# Processed sample 8095/152730
# Processed sample 8100/152730
# Processed sample 8105/152730
# Processed sample 8110/152730
# Processed sample 8115/152730
# Processed sample 8120/152730
# Processed sample 8125/152730
# Processed sample 8130/152730
# Processed sample 8135/152730
# Processed sample 8140/152730
# Processed sample 8145/152730
# Processed sample 8150/152730
# Processed sample 8155/152730
# Processed sample 8160/152730
# Processed sample 8165/152730
# Processed sample 8170/152730
# Processed sample 8175/152730
# Processed sample 8180/152730
# Processed sample 8185/152730
# Processed sample 8190/152730
# Processed sample 8195/152730
# Processed sample 8200/152730
# Processed sample 8205/152730
# Processed sample 8210/152730
# Processed sample 8215/152730
# Processed sample 8220/152730
# Processed sample 8225/152730
# Processed sample 8230/152730
# Processed sample 8235/152730
# Processed sample 8240/152730
# Processed sample 8245/152730
# Processed sample 8250/152730
# Processed sample 8255/152730
# Processed sample 8260/152730
# Processed sample 8265/152730
# Processed sample 8270/152730
# Processed sample 8275/152730
# Processed sample 8280/152730
# Processed sample 8285/152730
# Processed sample 8290/152730
# Processed sample 8295/152730
# Processed sample 8300/152730
# Processed sample 8305/152730
# ...
# Processed sample 150190/152730
# Processed sample 150195/152730
# Processed sample 150200/152730
# Processed sample 150205/152730
# Processed sample 150210/152730
# Processed sample 150215/152730
# Processed sample 150220/152730
# Processed sample 150225/152730
# Processed sample 150230/152730
# Processed sample 150235/152730
# Processed sample 150240/152730
# Processed sample 150245/152730
# Processed sample 150250/152730
# Processed sample 150255/152730
# Processed sample 150260/152730
# Processed sample 150265/152730
# Processed sample 150270/152730
# Processed sample 150275/152730
# Processed sample 150280/152730
# Processed sample 150285/152730
# Processed sample 150290/152730
# Processed sample 150295/152730
# Processed sample 150300/152730
# Processed sample 150305/152730
# Processed sample 150310/152730
# Processed sample 150315/152730
# Processed sample 150320/152730
# Processed sample 150325/152730
# Processed sample 150330/152730
# Processed sample 150335/152730
# Processed sample 150340/152730
# Processed sample 150345/152730
# Processed sample 150350/152730
# Processed sample 150355/152730
# Processed sample 150360/152730
# Processed sample 150365/152730
# Processed sample 150370/152730
# Processed sample 150375/152730
# Processed sample 150380/152730
# Processed sample 150385/152730
# Processed sample 150390/152730
# Processed sample 150395/152730
# Processed sample 150400/152730
# Processed sample 150405/152730
# Processed sample 150410/152730
# Processed sample 150415/152730
# Processed sample 150420/152730
# Processed sample 150425/152730
# Processed sample 150430/152730
# Processed sample 150435/152730
# Processed sample 150440/152730
# Processed sample 150445/152730
# Processed sample 150450/152730
# Processed sample 150455/152730
# Processed sample 150460/152730
# Processed sample 150465/152730
# Processed sample 150470/152730
# Processed sample 150475/152730
# Processed sample 150480/152730
# Processed sample 150485/152730
# Processed sample 150490/152730
# Processed sample 150495/152730
# Processed sample 150500/152730
# Processed sample 150505/152730
# Processed sample 150510/152730
# Processed sample 150515/152730
# Processed sample 150520/152730
# Processed sample 150525/152730
# Processed sample 150530/152730
# Processed sample 150535/152730
# Processed sample 150540/152730
# Processed sample 150545/152730
# Processed sample 150550/152730
# Processed sample 150555/152730
# Processed sample 150560/152730
# Processed sample 150565/152730
# Processed sample 150570/152730
# Processed sample 150575/152730
# Processed sample 150580/152730
# Processed sample 150585/152730
# Processed sample 150590/152730
# Processed sample 150595/152730
# Processed sample 150600/152730
# Processed sample 150605/152730
# Processed sample 150610/152730
# Processed sample 150615/152730
# Processed sample 150620/152730
# Processed sample 150625/152730
# Processed sample 150630/152730
# Processed sample 150635/152730
# Processed sample 150640/152730
# Processed sample 150645/152730
# Processed sample 150650/152730
# Processed sample 150655/152730
# Processed sample 150660/152730
# Processed sample 150665/152730
# Processed sample 150670/152730
# Processed sample 150675/152730
# Processed sample 150680/152730
# Processed sample 150685/152730
# Processed sample 150690/152730
# Processed sample 150695/152730
# Processed sample 150700/152730
# Processed sample 150705/152730
# Processed sample 150710/152730
# Processed sample 150715/152730
# Processed sample 150720/152730
# Processed sample 150725/152730
# Processed sample 150730/152730
# Processed sample 150735/152730
# Processed sample 150740/152730
# Processed sample 150745/152730
# Processed sample 150750/152730
# Processed sample 150755/152730
# Processed sample 150760/152730
# Processed sample 150765/152730
# Processed sample 150770/152730
# Processed sample 150775/152730
# Processed sample 150780/152730
# Processed sample 150785/152730
# Processed sample 150790/152730
# Processed sample 150795/152730
# Processed sample 150800/152730
# Processed sample 150805/152730
# Processed sample 150810/152730
# Processed sample 150815/152730
# Processed sample 150820/152730
# Processed sample 150825/152730
# Processed sample 150830/152730
# Processed sample 150835/152730
# Processed sample 150840/152730
# Processed sample 150845/152730
# Processed sample 150850/152730
# Processed sample 150855/152730
# Processed sample 150860/152730
# Processed sample 150865/152730
# Processed sample 150870/152730
# Processed sample 150875/152730
# Processed sample 150880/152730
# Processed sample 150885/152730
# Processed sample 150890/152730
# Processed sample 150895/152730
# Processed sample 150900/152730
# Processed sample 150905/152730
# Processed sample 150910/152730
# Processed sample 150915/152730
# Processed sample 150920/152730
# Processed sample 150925/152730
# Processed sample 150930/152730
# Processed sample 150935/152730
# Processed sample 150940/152730
# Processed sample 150945/152730
# Processed sample 150950/152730
# Processed sample 150955/152730
# Processed sample 150960/152730
# Processed sample 150965/152730
# Processed sample 150970/152730
# Processed sample 150975/152730
# Processed sample 150980/152730
# Processed sample 150985/152730
# Processed sample 150990/152730
# Processed sample 150995/152730
# Processed sample 151000/152730
# Processed sample 151005/152730
# Processed sample 151010/152730
# Processed sample 151015/152730
# Processed sample 151020/152730
# Processed sample 151025/152730
# Processed sample 151030/152730
# Processed sample 151035/152730
# Processed sample 151040/152730
# Processed sample 151045/152730
# Processed sample 151050/152730
# Processed sample 151055/152730
# Processed sample 151060/152730
# Processed sample 151065/152730
# Processed sample 151070/152730
# Processed sample 151075/152730
# Processed sample 151080/152730
# Processed sample 151085/152730
# Processed sample 151090/152730
# Processed sample 151095/152730
# Processed sample 151100/152730
# Processed sample 151105/152730
# Processed sample 151110/152730
# Processed sample 151115/152730
# Processed sample 151120/152730
# Processed sample 151125/152730
# Processed sample 151130/152730
# Processed sample 151135/152730
# Processed sample 151140/152730
# Processed sample 151145/152730
# Processed sample 151150/152730
# Processed sample 151155/152730
# Processed sample 151160/152730
# Processed sample 151165/152730
# Processed sample 151170/152730
# Processed sample 151175/152730
# Processed sample 151180/152730
# Processed sample 151185/152730
# Processed sample 151190/152730
# Processed sample 151195/152730
# Processed sample 151200/152730
# Processed sample 151205/152730
# Processed sample 151210/152730
# Processed sample 151215/152730
# Processed sample 151220/152730
# Processed sample 151225/152730
# Processed sample 151230/152730
# Processed sample 151235/152730
# Processed sample 151240/152730
# Processed sample 151245/152730
# Processed sample 151250/152730
# Processed sample 151255/152730
# Processed sample 151260/152730
# Processed sample 151265/152730
# Processed sample 151270/152730
# Processed sample 151275/152730
# Processed sample 151280/152730
# Processed sample 151285/152730
# Processed sample 151290/152730
# Processed sample 151295/152730
# Processed sample 151300/152730
# Processed sample 151305/152730
# Processed sample 151310/152730
# Processed sample 151315/152730
# Processed sample 151320/152730
# Processed sample 151325/152730
# Processed sample 151330/152730
# Processed sample 151335/152730
# Processed sample 151340/152730
# Processed sample 151345/152730
# Processed sample 151350/152730
# Processed sample 151355/152730
# Processed sample 151360/152730
# Processed sample 151365/152730
# Processed sample 151370/152730
# Processed sample 151375/152730
# Processed sample 151380/152730
# Processed sample 151385/152730
# Processed sample 151390/152730
# Processed sample 151395/152730
# Processed sample 151400/152730
# Processed sample 151405/152730
# Processed sample 151410/152730
# Processed sample 151415/152730
# Processed sample 151420/152730
# Processed sample 151425/152730
# Processed sample 151430/152730
# Processed sample 151435/152730
# Processed sample 151440/152730
# Processed sample 151445/152730
# Processed sample 151450/152730
# Processed sample 151455/152730
# Processed sample 151460/152730
# Processed sample 151465/152730
# Processed sample 151470/152730
# Processed sample 151475/152730
# Processed sample 151480/152730
# Processed sample 151485/152730
# Processed sample 151490/152730
# Processed sample 151495/152730
# Processed sample 151500/152730
# Processed sample 151505/152730
# Processed sample 151510/152730
# Processed sample 151515/152730
# Processed sample 151520/152730
# Processed sample 151525/152730
# Processed sample 151530/152730
# Processed sample 151535/152730
# Processed sample 151540/152730
# Processed sample 151545/152730
# Processed sample 151550/152730
# Processed sample 151555/152730
# Processed sample 151560/152730
# Processed sample 151565/152730
# Processed sample 151570/152730
# Processed sample 151575/152730
# Processed sample 151580/152730
# Processed sample 151585/152730
# Processed sample 151590/152730
# Processed sample 151595/152730
# Processed sample 151600/152730
# Processed sample 151605/152730
# Processed sample 151610/152730
# Processed sample 151615/152730
# Processed sample 151620/152730
# Processed sample 151625/152730
# Processed sample 151630/152730
# Processed sample 151635/152730
# Processed sample 151640/152730
# Processed sample 151645/152730
# Processed sample 151650/152730
# Processed sample 151655/152730
# Processed sample 151660/152730
# Processed sample 151665/152730
# Processed sample 151670/152730
# Processed sample 151675/152730
# Processed sample 151680/152730
# Processed sample 151685/152730
# Processed sample 151690/152730
# Processed sample 151695/152730
# Processed sample 151700/152730
# Processed sample 151705/152730
# Processed sample 151710/152730
# Processed sample 151715/152730
# Processed sample 151720/152730
# Processed sample 151725/152730
# Processed sample 151730/152730
# Processed sample 151735/152730
# Processed sample 151740/152730
# Processed sample 151745/152730
# Processed sample 151750/152730
# Processed sample 151755/152730
# Processed sample 151760/152730
# Processed sample 151765/152730
# Processed sample 151770/152730
# Processed sample 151775/152730
# Processed sample 151780/152730
# Processed sample 151785/152730
# Processed sample 151790/152730
# Processed sample 151795/152730
# Processed sample 151800/152730
# Processed sample 151805/152730
# Processed sample 151810/152730
# Processed sample 151815/152730
# Processed sample 151820/152730
# Processed sample 151825/152730
# Processed sample 151830/152730
# Processed sample 151835/152730
# Processed sample 151840/152730
# Processed sample 151845/152730
# Processed sample 151850/152730
# Processed sample 151855/152730
# Processed sample 151860/152730
# Processed sample 151865/152730
# Processed sample 151870/152730
# Processed sample 151875/152730
# Processed sample 151880/152730
# Processed sample 151885/152730
# Processed sample 151890/152730
# Processed sample 151895/152730
# Processed sample 151900/152730
# Processed sample 151905/152730
# Processed sample 151910/152730
# Processed sample 151915/152730
# Processed sample 151920/152730
# Processed sample 151925/152730
# Processed sample 151930/152730
# Processed sample 151935/152730
# Processed sample 151940/152730
# Processed sample 151945/152730
# Processed sample 151950/152730
# Processed sample 151955/152730
# Processed sample 151960/152730
# Processed sample 151965/152730
# Processed sample 151970/152730
# Processed sample 151975/152730
# Processed sample 151980/152730
# Processed sample 151985/152730
# Processed sample 151990/152730
# Processed sample 151995/152730
# Processed sample 152000/152730
# Processed sample 152005/152730
# Processed sample 152010/152730
# Processed sample 152015/152730
# Processed sample 152020/152730
# Processed sample 152025/152730
# Processed sample 152030/152730
# Processed sample 152035/152730
# Processed sample 152040/152730
# Processed sample 152045/152730
# Processed sample 152050/152730
# Processed sample 152055/152730
# Processed sample 152060/152730
# Processed sample 152065/152730
# Processed sample 152070/152730
# Processed sample 152075/152730
# Processed sample 152080/152730
# Processed sample 152085/152730
# Processed sample 152090/152730
# Processed sample 152095/152730
# Processed sample 152100/152730
# Processed sample 152105/152730
# Processed sample 152110/152730
# Processed sample 152115/152730
# Processed sample 152120/152730
# Processed sample 152125/152730
# Processed sample 152130/152730
# Processed sample 152135/152730
# Processed sample 152140/152730
# Processed sample 152145/152730
# Processed sample 152150/152730
# Processed sample 152155/152730
# Processed sample 152160/152730
# Processed sample 152165/152730
# Processed sample 152170/152730
# Processed sample 152175/152730
# Processed sample 152180/152730
# Processed sample 152185/152730
# Processed sample 152190/152730
# Processed sample 152195/152730
# Processed sample 152200/152730
# Processed sample 152205/152730
# Processed sample 152210/152730
# Processed sample 152215/152730
# Processed sample 152220/152730
# Processed sample 152225/152730
# Processed sample 152230/152730
# Processed sample 152235/152730
# Processed sample 152240/152730
# Processed sample 152245/152730
# Processed sample 152250/152730
# Processed sample 152255/152730
# Processed sample 152260/152730
# Processed sample 152265/152730
# Processed sample 152270/152730
# Processed sample 152275/152730
# Processed sample 152280/152730
# Processed sample 152285/152730
# Processed sample 152290/152730
# Processed sample 152295/152730
# Processed sample 152300/152730
# Processed sample 152305/152730
# Processed sample 152310/152730
# Processed sample 152315/152730
# Processed sample 152320/152730
# Processed sample 152325/152730
# Processed sample 152330/152730
# Processed sample 152335/152730
# Processed sample 152340/152730
# Processed sample 152345/152730
# Processed sample 152350/152730
# Processed sample 152355/152730
# Processed sample 152360/152730
# Processed sample 152365/152730
# Processed sample 152370/152730
# Processed sample 152375/152730
# Processed sample 152380/152730
# Processed sample 152385/152730
# Processed sample 152390/152730
# Processed sample 152395/152730
# Processed sample 152400/152730
# Processed sample 152405/152730
# Processed sample 152410/152730
# Processed sample 152415/152730
# Processed sample 152420/152730
# Processed sample 152425/152730
# Processed sample 152430/152730
# Processed sample 152435/152730
# Processed sample 152440/152730
# Processed sample 152445/152730
# Processed sample 152450/152730
# Processed sample 152455/152730
# Processed sample 152460/152730
# Processed sample 152465/152730
# Processed sample 152470/152730
# Processed sample 152475/152730
# Processed sample 152480/152730
# Processed sample 152485/152730
# Processed sample 152490/152730
# Processed sample 152495/152730
# Processed sample 152500/152730
# Processed sample 152505/152730
# Processed sample 152510/152730
# Processed sample 152515/152730
# Processed sample 152520/152730
# Processed sample 152525/152730
# Processed sample 152530/152730
# Processed sample 152535/152730
# Processed sample 152540/152730
# Processed sample 152545/152730
# Processed sample 152550/152730
# Processed sample 152555/152730
# Processed sample 152560/152730
# Processed sample 152565/152730
# Processed sample 152570/152730
# Processed sample 152575/152730
# Processed sample 152580/152730
# Processed sample 152585/152730
# Processed sample 152590/152730
# Processed sample 152595/152730
# Processed sample 152600/152730
# Processed sample 152605/152730
# Processed sample 152610/152730
# Processed sample 152615/152730
# Processed sample 152620/152730
# Processed sample 152625/152730
# Processed sample 152630/152730
# Processed sample 152635/152730
# Processed sample 152640/152730
# Processed sample 152645/152730
# Processed sample 152650/152730
# Processed sample 152655/152730
# Processed sample 152660/152730
# Processed sample 152665/152730
# Processed sample 152670/152730
# Processed sample 152675/152730
# Processed sample 152680/152730
# Processed sample 152685/152730
# Processed sample 152690/152730
# Processed sample 152695/152730
# Processed sample 152700/152730
# Processed sample 152705/152730
# Processed sample 152710/152730
# Processed sample 152715/152730
# Processed sample 152720/152730
# Processed sample 152725/152730
# Bandpass filtering completed for all samples.
# Filtered EEG Data Shape: (62, 200)
# Label: {'start_at': 0, 'end_at': 200, 'clip_id': '10_20131130.mat_0', 'subject_id': 10, 'trial_id': 'ww_eeg1', 'emotion': 1, 'date': 20131130, '_record_id': '_record_0'}

# %%
import numpy as np
import random
from collections import defaultdict

def generate_contrastive_minibatch(filtered_data_list, labels_list, batch_size=32, pairs_per_sample=4):
    """
    Generate a minibatch with multiple positive and negative pairs for each sample.
    Positive pairs are from trials with the same emotion.
    Negative pairs are from trials with different emotions.

    Args:
        filtered_data_list: List of filtered EEG data (one entry per segment).
        labels_list: List of corresponding labels (each label contains subject_id, trial_id, emotion).
        batch_size: Desired number of samples in each minibatch.
        pairs_per_sample: Number of pairs to generate per sample (both positive and negative).

    Returns:
        A tuple (minibatch, pair_labels), where:
        - minibatch: List of tuples (sample_A, sample_B)
        - pair_labels: List indicating if the pair is positive (1) or negative (0)
    """
  # Group data by emotion for efficient sampling
    emotion_map = defaultdict(list)
    for idx, label in enumerate(labels_list):
        emotion = label['emotion']
        emotion_map[emotion].append(idx)

    # List of unique emotions
    emotions = list(emotion_map.keys())

    # Select a random subset of samples for the minibatch
    all_indices = list(range(len(filtered_data_list)))
    minibatch_indices = random.sample(all_indices, batch_size)

    minibatch = []
    pair_labels = []

    for idx in minibatch_indices:
        sample_A = filtered_data_list[idx]
        label_A = labels_list[idx]
        emotion_A = label_A['emotion']

        # Generate positive pairs (same emotion)
        if len(emotion_map[emotion_A]) > 1:
            positive_indices = [i for i in emotion_map[emotion_A] if i != idx]
            pos_idx = random.choice(positive_indices)
            minibatch.append((sample_A, filtered_data_list[pos_idx]))
            pair_labels.append(1)

        # Generate negative pairs (different emotions)
        negative_emotions = [e for e in emotions if e != emotion_A]
        neg_emotion = random.choice(negative_emotions)
        neg_idx = random.choice(emotion_map[neg_emotion])
        minibatch.append((sample_A, filtered_data_list[neg_idx]))
        pair_labels.append(0)

    # Shuffle the pairs to mix positive and negative pairs
    combined = list(zip(minibatch, pair_labels))
    random.shuffle(combined)
    minibatch, pair_labels = zip(*combined)

    return minibatch, pair_labels

# %%
minibatch, pair_labels = generate_contrastive_minibatch(filtered_data_list, labels_list, batch_size=512, pairs_per_sample=4)

# Count positive and negative pairs
num_positive = sum(pair_labels)
num_negative = len(pair_labels) - num_positive

print(f"Number of Positive Pairs: {num_positive}")
print(f"Number of Negative Pairs: {num_negative}")
# Out:
# Number of Positive Pairs: 512
# Number of Negative Pairs: 512

# %%
import torch
import torch.nn.functional as F

def contrastive_loss(embeddings_A, embeddings_B, pair_labels, temperature=0.1):
    """
    Compute the contrastive loss for a minibatch.

    Args:
        embeddings_A: Tensor of embeddings for the first element in each pair.
        embeddings_B: Tensor of embeddings for the second element in each pair.
        pair_labels: Tensor indicating if the pair is positive (1) or negative (0).
        temperature: Temperature scaling parameter for contrastive loss.

    Returns:
        Computed contrastive loss.
    """
    # Compute cosine similarity
    cosine_sim = F.cosine_similarity(embeddings_A, embeddings_B)
    
    # Scale the similarities by the temperature
    logits = cosine_sim / temperature
    
    # Compute binary cross-entropy loss
    loss = F.binary_cross_entropy_with_logits(logits, pair_labels.float())
    
    return loss

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class BaseEncoder(nn.Module):
    def __init__(self, num_channels=62, temporal_filter_length=48, num_spatial_filters=16, num_temporal_filters=16):
        super(BaseEncoder, self).__init__()

        # Spatial Convolution: [batch_size, num_channels, timepoints] -> [batch_size, num_spatial_filters, timepoints]
        self.spatial_conv = nn.Conv1d(
            in_channels=num_channels,
            out_channels=num_spatial_filters,
            kernel_size=1,
            bias=False
        )
        
        # Temporal Convolution: [batch_size, num_spatial_filters, timepoints] -> [batch_size, num_temporal_filters, timepoints]
        self.temporal_conv = nn.Conv1d(
            in_channels=num_spatial_filters,
            out_channels=num_temporal_filters,
            kernel_size=temporal_filter_length,
            padding='same',  # Ensure output length matches input length
            bias=False
        )

        # Batch Normalization for stability
        self.bn_spatial = nn.BatchNorm1d(num_spatial_filters)
        self.bn_temporal = nn.BatchNorm1d(num_temporal_filters)

        # Activation Function
        self.activation = nn.ELU()

    def forward(self, x):
        # x shape: [batch_size, num_channels, timepoints]
        
        # Spatial Convolution + BatchNorm + ReLU
        x = self.spatial_conv(x)
        x = self.bn_spatial(x)
        x = self.activation(x)
        
        # Temporal Convolution + BatchNorm + ReLU
        x = self.temporal_conv(x)
        x = self.bn_temporal(x)
        x = self.activation(x)
        
        return x

# Initialize the Base Encoder
base_encoder = BaseEncoder()

# Verify the model with a sample input
sample_input = torch.randn(32, 62, 200)  # Batch size = 32, Channels = 62, Timepoints = 200
output = base_encoder(sample_input)

print(f"Input Shape: {sample_input.shape}")
print(f"Output Shape: {output.shape}")  # Expected: [32, 16, 200]
# Out:
# Input Shape: torch.Size([32, 62, 200])
# Output Shape: torch.Size([32, 16, 200])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Projector(nn.Module):
    def __init__(self, num_input_filters=16, spatial_filters=32, temporal_filters=64, temporal_filter_length=4, pooling_kernel_length=24):
        super(Projector, self).__init__()

        # Spatial Convolution: [batch_size, num_input_filters, timepoints] -> [batch_size, spatial_filters, timepoints]
        self.spatial_conv = nn.Conv1d(
            in_channels=num_input_filters,
            out_channels=spatial_filters,
            kernel_size=1,
            bias=False
        )

        # Temporal Convolution: [batch_size, spatial_filters, timepoints] -> [batch_size, temporal_filters, timepoints]
        # Padding to maintain the same output length as input length
        self.temporal_conv = nn.Conv1d(
            in_channels=spatial_filters,
            out_channels=temporal_filters,
            kernel_size=temporal_filter_length,
            padding=temporal_filter_length // 2,
            bias=False
        )

        # Average Pooling: [batch_size, temporal_filters, timepoints] -> [batch_size, temporal_filters, reduced_timepoints]
        self.avg_pool = nn.AvgPool1d(kernel_size=pooling_kernel_length)

        # Batch Normalization
        self.bn_spatial = nn.BatchNorm1d(spatial_filters)
        self.bn_temporal = nn.BatchNorm1d(temporal_filters)

        # Activation Function
        self.activation = nn.ELU()

    def forward(self, x):
        # x shape: [batch_size, num_input_filters, timepoints]
        
        # Spatial Convolution + BatchNorm + ReLU
        x = self.spatial_conv(x)
        x = self.bn_spatial(x)
        x = self.activation(x)

        # Temporal Convolution + BatchNorm + ReLU
        x = self.temporal_conv(x)
        x = self.bn_temporal(x)
        x = self.activation(x)

        # Average Pooling
        x = self.avg_pool(x)

        return x

# Initialize the Projector with SEED hyperparameters
projector = Projector(
    num_input_filters=16,         # Output from the base encoder
    spatial_filters=32,           # CK2 = 32
    temporal_filters=64,          # C^2K2 = 64
    temporal_filter_length=4,     # P2 = 4
    pooling_kernel_length=24      # S = 24
)

# Verify the model with a sample input
sample_input = torch.randn(32, 16, 200)  # Batch size = 32, Input filters = 16, Timepoints = 200
output = projector(sample_input)

print(f"Input Shape: {sample_input.shape}")
print(f"Output Shape: {output.shape}")  # Expected: [32, 64, reduced_timepoints]
# Out:
# Input Shape: torch.Size([32, 16, 200])
# Output Shape: torch.Size([32, 64, 8])

# %%
def generate_embeddings(minibatch, encoder, projector, device):
    embeddings_A = []
    embeddings_B = []

    for sample_A, sample_B in minibatch:
        tensor_A = torch.tensor(sample_A, dtype=torch.float32).unsqueeze(0).to(device)
        tensor_B = torch.tensor(sample_B, dtype=torch.float32).unsqueeze(0).to(device)

        # Get encoded features and projected embeddings
        embedding_A = projector(encoder(tensor_A))
        embedding_B = projector(encoder(tensor_B))

        embeddings_A.append(embedding_A)
        embeddings_B.append(embedding_B)

    # Stack embeddings
    embeddings_A = torch.cat(embeddings_A, dim=0)
    embeddings_B = torch.cat(embeddings_B, dim=0)

    return embeddings_A, embeddings_B

# %%
import torch.nn.functional as F

def contrastive_loss(embeddings_A, embeddings_B, pair_labels, temperature=0.1):
    """
    Compute the contrastive loss for a minibatch.

    Args:
        embeddings_A: Tensor of embeddings for the first element in each pair.
        embeddings_B: Tensor of embeddings for the second element in each pair.
        pair_labels: Tensor indicating if the pair is positive (1) or negative (0).
        temperature: Temperature scaling parameter for contrastive loss.

    Returns:
        Computed contrastive loss.
    """
    embeddings_A = F.normalize(embeddings_A, p=2, dim=1)
    embeddings_B = F.normalize(embeddings_B, p=2, dim=1)
    
    # Compute cosine similarity
    cosine_sim = F.cosine_similarity(embeddings_A, embeddings_B)
    
    # Scale the similarities by the temperature
    logits = cosine_sim / temperature
    
    # pair_labels = pair_labels.squeeze()
    
    # Compute binary cross-entropy loss
    loss = F.binary_cross_entropy_with_logits(logits, pair_labels.float())
    
    return loss

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.utils import tensorboard

# Define the Encoder and Projector (assuming these are already defined)
encoder = BaseEncoder()    # Replace with your actual BaseEncoder class
projector = Projector()    # Replace with your actual Projector class
writer = tensorboard.SummaryWriter(log_dir='E:/FYP/Egg-Based Emotion Recognition/EEg-based-Emotion-Recognition/runs/contrastive_pakka')
# Move models to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
encoder.to(device)
projector.to(device)

# Optimizer and Scheduler
optimizer = Adam(list(encoder.parameters()) + list(projector.parameters()), lr=0.0007, weight_decay=0.015)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)

# Early Stopping Parameters
best_loss = float('inf')
patience = 30
counter = 0

# Training Loop
num_epochs = 100
scaler = torch.amp.GradScaler()

for epoch in range(num_epochs):
    encoder.train()
    projector.train()

    # Generate a minibatch of pairs and labels
    minibatch, pair_labels = generate_contrastive_minibatch(filtered_data_list, labels_list, batch_size=256, pairs_per_sample=4)
    pair_labels = torch.tensor(pair_labels, dtype=torch.float32).to(device)

    # Generate embeddings
    embeddings_A, embeddings_B = [], []

    for sample_A, sample_B in minibatch:
        tensor_A = torch.tensor(sample_A.copy(), dtype=torch.float32).unsqueeze(0).to(device)
        tensor_B = torch.tensor(sample_B.copy(), dtype=torch.float32).unsqueeze(0).to(device)
        
        with torch.amp.autocast(device_type=device.type):
            embedding_A = projector(encoder(tensor_A))
            embedding_B = projector(encoder(tensor_B))

        embeddings_A.append(embedding_A.cpu())
        embeddings_B.append(embedding_B.cpu())
        
        del tensor_A, tensor_B, embedding_A, embedding_B
        torch.cuda.empty_cache()


    embeddings_A = torch.cat(embeddings_A, dim=0).to(device)
    embeddings_B = torch.cat(embeddings_B, dim=0).to(device)
    
    embeddings_A = torch.mean(embeddings_A, dim=2)  # Shape: [batch_size, channels]
    embeddings_B = torch.mean(embeddings_B, dim=2)  # Shape: [batch_size, channels]


    embeddings_A = embeddings_A.view(embeddings_A.size(0), -1)
    embeddings_B = embeddings_B.view(embeddings_B.size(0), -1)
    
    print(f"logits shape: {embeddings_A.shape}, pair_labels shape: {pair_labels.shape}")


    with torch.amp.autocast(device_type=device.type):
    # Compute contrastive loss
        loss = contrastive_loss(embeddings_A, embeddings_B, pair_labels)

    optimizer.zero_grad()
    scaler.scale(loss).backward()
    scaler.step(optimizer)
    scaler.update()
    scheduler.step()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")
    writer.add_scalar('Loss/train', loss.item(), epoch)

    # Early stopping
    if loss < best_loss:
        best_loss = loss
        torch.save({'encoder': encoder.state_dict(), 'projector': projector.state_dict()}, 'best_model.pth')
        counter = 0
    else:
        counter += 1

    if counter >= patience:
        print("Early stopping triggered")
        break

print("Training Complete.")
writer.close()
# Out:
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [1/100], Loss: 4.9301
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [2/100], Loss: 4.9055
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [3/100], Loss: 4.8734
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [4/100], Loss: 4.8415
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [5/100], Loss: 4.7819
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [6/100], Loss: 4.7698
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [7/100], Loss: 4.7257
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [8/100], Loss: 4.7043
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [9/100], Loss: 4.6883
# logits shape: torch.Size([512, 64]), pair_labels shape: torch.Size([512])
# Epoch [10/100], Loss: 4.7004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 35
#      32 projector.train()
#      34 # Generate a minibatch of pairs and labels
# ---> 35 minibatch, pair_labels = generate_contrastive_minibatch(filtered_data_list, labels_list, batch_size=256, pairs_per_sample=4)
#      36 pair_labels = torch.tensor(pair_labels, dtype=torch.float32).to(device)
#      38 # Generate embeddings
#
# Cell In[36], line 45, in generate_contrastive_minibatch(filtered_data_list, labels_list, batch_size, pairs_per_sample)
#      43 # Generate positive pairs (same emotion)
#      44 if len(emotion_map[emotion_A]) > 1:
# ---> 45     positive_indices = [i for i in emotion_map[emotion_A] if i != idx]
#      46     pos_idx = random.choice(positive_indices)
#      47     minibatch.append((sample_A, filtered_data_list[pos_idx]))
#
# KeyboardInterrupt:

# %%
print("Checking sample pairs:")
for i in range(20):
    print(f"Pair {i + 1}: Label = {pair_labels[i]}")
# Out:
# Checking sample pairs:
# Pair 1: Label = 0
# Pair 2: Label = 0
# Pair 3: Label = 1
# Pair 4: Label = 1
# Pair 5: Label = 1
# Pair 6: Label = 1
# Pair 7: Label = 0
# Pair 8: Label = 1
# Pair 9: Label = 0
# Pair 10: Label = 0
# Pair 11: Label = 0
# Pair 12: Label = 0
# Pair 13: Label = 0
# Pair 14: Label = 1
# Pair 15: Label = 0
# Pair 16: Label = 0
# Pair 17: Label = 0
# Pair 18: Label = 1
# Pair 19: Label = 1
# Pair 20: Label = 0
